# %%
import bokeh.plotting

# %%
bokeh.plotting.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="eefef6b0-9a56-461e-9954-9be1d6697a6e">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.palettes import Category10_10 as palette

# %%
import numpy as np

# %%
import scipy.stats

# %% [markdown]
# # Decision Tree

# %% [markdown]
# ## Play Tennis

# %% [markdown]
# Figure \ref{fig:tennistree} is an example of using \cite{scikit-learn} to generate a decision tree.

# %%
# %%capture
from datasets.play_tennis import load_play_tennis
from sklearn import tree
play_tennis = load_play_tennis()
clf = tree.DecisionTreeClassifier()
clf = clf.fit(play_tennis.data, play_tennis.target)

dot_data = tree.export_graphviz(clf, out_file=None,
                         feature_names=play_tennis.feature_names,  
                         class_names=play_tennis.target_names,  
                         filled=True, rounded=True,  
                         special_characters=True)  

import graphviz 
graph = graphviz.Source(dot_data, format='png')
graph.render('img/tennis_tree')

# %% [raw]
#
#     \begin{figure}[h!]
#       \centering
#       \includegraphics{img/tennis_tree.png}
#       \caption{The playtennis decision tree}
#       \label{fig:tennistree}
# 	\end{figure}

# %% [markdown]
# # Sample plot

# %% [markdown]
# Bokeh expects data as either a **single value**, or a **series of values**, e.g., list, set, NumPy array, Pandas DataFrame column.  We will often use NumPy arrays. We used \cite{DUMMY:1}.
#
# Lets create some sample data.  Throughout this tutorial, we will use the [normal (or Gaussian) distribution](https://en.wikipedia.org/wiki/Normal_distribution) for out sample data.  The Gaussian distribution is defined as

# %% [markdown]
# $$f(x | \mu, \sigma^2) = \frac{1}{\sqrt{2\pi\sigma^2}} \,\exp\left({-\frac{(x-\mu)^2}{2\sigma^2}}\right)$$

# %% [markdown]
# where $\mu$ is the mean value, and $\sigma$ is the standard deviation. See Figure \ref{fig:nice}.
#
# SciPy provides [`scipy.stats.norm`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.norm.html) which include many functions related to the Gaussian distribution.  Here is a simple wrapper of the probability density function (pdf).

# %%
def gaussian(x_array, mu, sigma):
    pdf = scipy.stats.norm.pdf(x_array, loc=mu, scale=sigma)
    return pdf

# %% [markdown]
# ## A Pretty Good Plot

# %% [markdown]
# We will define 3 Gaussian distributions:
# 1. $\mu=10$, $\sigma=4$
# 2. $\mu=15$, $\sigma=1$
# 3. $\mu=8$, $\sigma=2$

# %%
x = np.linspace(0, 20, 100)
y1 = gaussian(x, 10, 4)
y2 = gaussian(x, 15, 1)
y3 = gaussian(x, 8, 2)

# %%
p = bokeh.plotting.figure()
p.diamond(x, y1)
bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e8cb12c1-cf7e-4545-ab4f-a18a9d2c2ec1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("e8cb12c1-cf7e-4545-ab4f-a18a9d2c2ec1");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e8cb12c1-cf7e-4545-ab4f-a18a9d2c2ec1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e8cb12c1-cf7e-4545-ab4f-a18a9d2c2ec1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9b61fa60-07cc-4c42-95f0-05bb8a48070d":{"roots":{"references":[{"attributes":{"plot":{"id":"4b3887ea-526a-404c-859f-3c404a374bc9","subtype":"Figure","type":"Plot"}},"id":"45ab171c-22aa-4502-af07-eb87758d7eff","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"4b3887ea-526a-404c-859f-3c404a374bc9","subtype":"Figure","type":"Plot"}},"id":"488d7895-f5fc-4f32-b13d-7b05d69d1095","type":"ResetTool"},{"attributes":{"plot":{"id":"4b3887ea-526a-404c-859f-3c404a374bc9","subtype":"Figure","type":"Plot"}},"id":"5d2e5e5f-26c8-4313-96ef-225144a4b1d5","type":"SaveTool"},{"attributes":{},"id":"34f52496-3df5-4db2-9a0d-8f7951fc30af","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":""},"id":"eb6ac4dc-f8cc-4f76-8c53-485812cfe39a","type":"Title"},{"attributes":{"below":[{"id":"5d12e37f-6ba8-4deb-8013-ae2d35da5bc8","type":"LinearAxis"}],"left":[{"id":"b38b8510-4565-4c3d-af12-99a000988f86","type":"LinearAxis"}],"renderers":[{"id":"5d12e37f-6ba8-4deb-8013-ae2d35da5bc8","type":"LinearAxis"},{"id":"d1f92c53-1b3a-4b85-b3a5-a3dc954a097b","type":"Grid"},{"id":"b38b8510-4565-4c3d-af12-99a000988f86","type":"LinearAxis"},{"id":"b5a2bf38-ed87-4659-bcbb-299b0341fc6b","type":"Grid"},{"id":"49b14ed2-2521-410b-8837-42163f05ed00","type":"BoxAnnotation"},{"id":"74a8cf56-376e-4f32-becd-be41aeb57c6b","type":"GlyphRenderer"}],"title":{"id":"eb6ac4dc-f8cc-4f76-8c53-485812cfe39a","type":"Title"},"tool_events":{"id":"255f4ced-f82a-4a0f-8d10-cd6cb1a572dc","type":"ToolEvents"},"toolbar":{"id":"3f6cbe68-ff7d-4114-b530-5d5f253b96bf","type":"Toolbar"},"x_range":{"id":"ad3cdc8f-819a-4b82-9c2d-ecd1ec31c7dd","type":"DataRange1d"},"x_scale":{"id":"3910d68c-b600-46e0-9262-1da5cccd4bf1","type":"LinearScale"},"y_range":{"id":"82743b52-7e11-454a-baa2-ff0ca98970f9","type":"DataRange1d"},"y_scale":{"id":"efbb4a23-dd5e-4b16-951c-1c3e521330b4","type":"LinearScale"}},"id":"4b3887ea-526a-404c-859f-3c404a374bc9","subtype":"Figure","type":"Plot"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"67f1e879-1744-470f-996d-61832938cc8d","type":"Diamond"},{"attributes":{},"id":"255f4ced-f82a-4a0f-8d10-cd6cb1a572dc","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[100]},"y":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"a751eea2-6f97-429f-ac9b-8f1853d572fa","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"4b3887ea-526a-404c-859f-3c404a374bc9","subtype":"Figure","type":"Plot"},"ticker":{"id":"d935d270-8f4b-4681-adb9-efd0c3d5f02d","type":"BasicTicker"}},"id":"b5a2bf38-ed87-4659-bcbb-299b0341fc6b","type":"Grid"},{"attributes":{"callback":null},"id":"ad3cdc8f-819a-4b82-9c2d-ecd1ec31c7dd","type":"DataRange1d"},{"attributes":{"overlay":{"id":"49b14ed2-2521-410b-8837-42163f05ed00","type":"BoxAnnotation"},"plot":{"id":"4b3887ea-526a-404c-859f-3c404a374bc9","subtype":"Figure","type":"Plot"}},"id":"72e0e2e6-8051-486c-9b4b-62e0b4b1fb3a","type":"BoxZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"49b14ed2-2521-410b-8837-42163f05ed00","type":"BoxAnnotation"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"542a6ca7-0ec6-46ee-b39e-95bf6c718248","type":"PanTool"},{"id":"45ab171c-22aa-4502-af07-eb87758d7eff","type":"WheelZoomTool"},{"id":"72e0e2e6-8051-486c-9b4b-62e0b4b1fb3a","type":"BoxZoomTool"},{"id":"5d2e5e5f-26c8-4313-96ef-225144a4b1d5","type":"SaveTool"},{"id":"488d7895-f5fc-4f32-b13d-7b05d69d1095","type":"ResetTool"},{"id":"b92ddb3e-ec16-441e-98d8-3cc0242ce306","ty ...

# %% [raw]
#
#     \begin{figure}[h!]
#       \centering
#       \includegraphics{img/nice.png}
#       \caption{A nice curve}
#       \label{fig:nice}
# 	\end{figure}

# %% [markdown]
# In addition to `tools`, `figure()` and `diamond()` have several other `kwargs` you can use to adjust the plotting results.  Lets see some of these in use.

# %%
p = bokeh.plotting.figure(
    title='Demo Plot',
    x_axis_label='x',
    y_axis_label='f(x)',
    width=500, height=350,
    x_range=(0, 20),
    y_range=(-0.05, 0.12),
)

p.diamond(x, y1, 
          line_color=palette[0], 
          fill_color=palette[1],
          line_alpha=y1/y1.max(), # oscillate from 0 to 1 (y min to max)
          fill_alpha=(1-y1/y1.max()), # oscillate from 1 to 0 (y min to max)
          legend='m=10, s=4', 
          size=x/1.5)

bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ca7aa8cd-8538-4b79-8c92-cf28ffa0c19f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("ca7aa8cd-8538-4b79-8c92-cf28ffa0c19f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ca7aa8cd-8538-4b79-8c92-cf28ffa0c19f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ca7aa8cd-8538-4b79-8c92-cf28ffa0c19f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"cb19877e-ec62-4acc-86a5-d09a4fbfa239":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"3499dc98-8bb8-498f-a362-a548a8aff9b2","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"daf21728-ead8-48fd-a593-ad482ecf1670","subtype":"Figure","type":"Plot"}},"id":"038dd929-a099-4c80-9acb-d7250c0f5754","type":"WheelZoomTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"208b8463-58ff-4482-aa65-877a8fd0ace8","type":"PanTool"},{"id":"038dd929-a099-4c80-9acb-d7250c0f5754","type":"WheelZoomTool"},{"id":"c8e1646b-8271-4cd4-91d1-b3c91369a48d","type":"BoxZoomTool"},{"id":"628c96de-ab0f-4c10-bfb6-a1207900b9de","type":"SaveTool"},{"id":"6896995a-c46f-4da9-a39b-49fe34b6c8c3","type":"ResetTool"},{"id":"56bd5212-c40d-4dda-9bfc-1875f5770139","type":"HelpTool"}]},"id":"7033d55d-ca90-4140-9575-a88745f35288","type":"Toolbar"},{"attributes":{"overlay":{"id":"3499dc98-8bb8-498f-a362-a548a8aff9b2","type":"BoxAnnotation"},"plot":{"id":"daf21728-ead8-48fd-a593-ad482ecf1670","subtype":"Figure","type":"Plot"}},"id":"c8e1646b-8271-4cd4-91d1-b3c91369a48d","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"daf21728-ead8-48fd-a593-ad482ecf1670","subtype":"Figure","type":"Plot"}},"id":"628c96de-ab0f-4c10-bfb6-a1207900b9de","type":"SaveTool"},{"attributes":{},"id":"3004c717-ca09-4d6a-b83d-13b49fbcbe1b","type":"LinearScale"},{"attributes":{"plot":{"id":"daf21728-ead8-48fd-a593-ad482ecf1670","subtype":"Figure","type":"Plot"}},"id":"6896995a-c46f-4da9-a39b-49fe34b6c8c3","type":"ResetTool"},{"attributes":{"callback":null,"end":0.12,"start":-0.05},"id":"be4fbf0a-7952-4eb2-bb23-c5ec7310e420","type":"Range1d"},{"attributes":{"plot":{"id":"daf21728-ead8-48fd-a593-ad482ecf1670","subtype":"Figure","type":"Plot"}},"id":"56bd5212-c40d-4dda-9bfc-1875f5770139","type":"HelpTool"},{"attributes":{},"id":"38e8508d-339c-4648-b427-368efd36794c","type":"LinearScale"},{"attributes":{"plot":{"id":"daf21728-ead8-48fd-a593-ad482ecf1670","subtype":"Figure","type":"Plot"},"ticker":{"id":"c063772d-b13f-4928-84b3-efe48ecf7d47","type":"BasicTicker"}},"id":"b4fb4fb3-1816-43c3-a8ac-496475a837ef","type":"Grid"},{"attributes":{"axis_label":"x","formatter":{"id":"8000bba0-85c1-4aaa-88a9-544c18950857","type":"BasicTickFormatter"},"plot":{"id":"daf21728-ead8-48fd-a593-ad482ecf1670","subtype":"Figure","type":"Plot"},"ticker":{"id":"c063772d-b13f-4928-84b3-efe48ecf7d47","type":"BasicTicker"}},"id":"baf591fb-6202-4964-995f-dd9aebc80084","type":"LinearAxis"},{"attributes":{"label":{"value":"m=10, s=4"},"renderers":[{"id":"f9cfe519-6bba-46d6-8b46-bae6d1b358dd","type":"GlyphRenderer"}]},"id":"4a2863a8-bb64-4af1-822a-7438fa08a31e","type":"LegendItem"},{"attributes":{},"id":"c063772d-b13f-4928-84b3-efe48ecf7d47","type":"BasicTicker"},{"attributes":{"axis_label":"f(x)","formatter":{"id":"d6aaadb5-eb40-4006-a171-1489895f8d6e","type":"BasicTickFormatter"},"plot":{"id":"daf21728-ead8-48fd-a593-ad482ecf1670","subtype":"Figure","type":"Plot"},"ticker":{"id":"c9da04d1-5b24-4982-b335-2c745a095539","type":"BasicTicker"}},"id":"6c863441-8bb2-4f5c-87c9-8605cb1141be","type":"LinearAxis"},{"attributes":{"items":[{"id":"4a2863a8-bb64-4af1-822a-7438fa08a31e","type":"LegendItem"}],"plot":{"id":"daf21728-ead8-48fd-a593-ad482ecf1670","subtype":"Figure","type":"Plot"}},"id":"37a0b8db-666f-4d48-b552-dfc6583b2b69","type":"Legend"},{"attributes":{},"id":"c9da04d1-5b24-4982-b335-2c745a095539","type":"BasicTicker"},{"attributes":{},"id":"d6aaadb5-eb40-4006-a171-1489895f8d6e","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y","size","fill_alpha","line_alpha"],"data":{"fill_alpha":{"__ndarray__":"...","dt ...

# %% [markdown]
# Note that you can use `color` to set both the `line_color` and `fill_color`.  Similarly, `alpha` sets both the `line_alpha` and `fill_alpha`. See Figure \ref{fig:nicer}.

# %%
p = bokeh.plotting.figure(
    title='Demo Plot',
    x_axis_label='x',
    y_axis_label='f(x)',
    width=500, height=350,
    x_range=(0, 20),
    y_range=(-0.05, 0.12),
)

p.diamond(
    x, y1, 
    color=palette[0], 
    alpha=y1/y1.max(), # oscillate from 0 to 1 (y min to max)
    legend='m=10 s=4', 
    size=x/1.5)

bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="967d8d73-9149-42b0-9693-58f65f80873e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("967d8d73-9149-42b0-9693-58f65f80873e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("967d8d73-9149-42b0-9693-58f65f80873e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '967d8d73-9149-42b0-9693-58f65f80873e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ec9c688c-ff87-43f7-8c44-78b1940f1ae2":{"roots":{"references":[{"attributes":{},"id":"0b60aaff-476d-49c8-a482-6448e63adb6d","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"76860deb-5de5-4531-a036-6feb84d4571d","subtype":"Figure","type":"Plot"}},"id":"2ebcf7a8-092a-4fb9-85d0-007480ee5b56","type":"WheelZoomTool"},{"attributes":{},"id":"de321a21-5886-4e18-95e5-dfc9e1953a28","type":"LinearScale"},{"attributes":{},"id":"3d326230-d2e6-48dd-917d-ba52707feecc","type":"LinearScale"},{"attributes":{"axis_label":"x","formatter":{"id":"0b60aaff-476d-49c8-a482-6448e63adb6d","type":"BasicTickFormatter"},"plot":{"id":"76860deb-5de5-4531-a036-6feb84d4571d","subtype":"Figure","type":"Plot"},"ticker":{"id":"cfc78a42-4c80-4b8e-843f-ffdf729d0d0d","type":"BasicTicker"}},"id":"e633b7d5-5740-49c0-98fa-6b0dc870e6d7","type":"LinearAxis"},{"attributes":{},"id":"3bae98ef-0a94-4e64-8e0a-c14c5936e90d","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"76860deb-5de5-4531-a036-6feb84d4571d","subtype":"Figure","type":"Plot"},"ticker":{"id":"eb8043b4-1c18-49b5-b7ac-3085a9071f83","type":"BasicTicker"}},"id":"6c55fa86-2ecc-459c-80ad-b675ce7e5a3e","type":"Grid"},{"attributes":{"callback":null,"column_names":["x","y","size","fill_alpha","line_alpha"],"data":{"fill_alpha":{"__ndarray__":"...","dtype":"float64","shape":[100]},"line_alpha":{"__ndarray__":"...","dtype":"float64","shape":[100]},"size":{"__ndarray__":"...","dtype":"float64","shape":[100]},"x":{"__ndarray__":"...","dtype":"float64","shape":[100]},"y":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"c07e96c3-c8cc-4431-9044-7c46951455fd","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"value":"#1f77b4"},"line_alpha":{"field":"line_alpha"},"line_color":{"value":"#1f77b4"},"size":{"field":"size","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"69750be0-1c33-4267-90ec-f509e21be57b","type":"Diamond"},{"attributes":{"callback":null,"end":20},"id":"61cd67ac-f228-403a-9812-d69bb500efb5","type":"Range1d"},{"attributes":{},"id":"eb8043b4-1c18-49b5-b7ac-3085a9071f83","type":"BasicTicker"},{"attributes":{"below":[{"id":"e633b7d5-5740-49c0-98fa-6b0dc870e6d7","type":"LinearAxis"}],"left":[{"id":"1a472397-3912-4e15-8b12-d55e80e6d0be","type":"LinearAxis"}],"plot_height":350,"plot_width":500,"renderers":[{"id":"e633b7d5-5740-49c0-98fa-6b0dc870e6d7","type":"LinearAxis"},{"id":"6a9dd616-60bd-4dc1-9209-2aa019be33e7","type":"Grid"},{"id":"1a472397-3912-4e15-8b12-d55e80e6d0be","type":"LinearAxis"},{"id":"6c55fa86-2ecc-459c-80ad-b675ce7e5a3e","type":"Grid"},{"id":"aa2ade40-9178-4af7-9b6c-57bedb1fae99","type":"BoxAnnotation"},{"id":"7f0ac531-4ca4-46a3-9d9a-9e96e7b6d7b8","type":"Legend"},{"id":"f3b337f0-b0a3-440f-8ad7-3b2de9c28823","type":"GlyphRenderer"}],"title":{"id":"8e0e9aa6-92ee-4cbb-bddd-855af65b38a5","type":"Title"},"tool_events":{"id":"3bae98ef-0a94-4e64-8e0a-c14c5936e90d","type":"ToolEvents"},"toolbar":{"id":"f1782c5a-a0c8-4f7a-a84d-a7828e82657f","type":"Toolbar"},"x_range":{"id":"61cd67ac-f228-403a-9812-d69bb500efb5","type":"Range1d"},"x_scale":{"id":"de321a21-5886-4e18-95e5-dfc9e1953a28","type":"LinearScale"},"y_range":{"id":"ac85018a-2242-425e-bc8f-73f247a21101","type":"Range1d"},"y_scale":{"id":"3d326230-d2e6-48dd-917d-ba52707feecc","type":"LinearScale"}},"id":"76860deb-5de5-4531-a036-6feb84d4571d","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"76860deb-5de5-4531-a036-6feb84d4571d","subtype":"Figure","type":"Plot"},"ticker":{"id":"cfc78a42-4c80-4b8e-843f-ffdf729d0d0d","type":"BasicTicker"}},"id":"6a9dd616-60bd-4dc1-9209-2aa019be33e7","type":"Grid"},{"attributes":{"callback":null,"end":0.12,"start":-0.05},"id":"ac85018a-2242-425e-bc8f-73f247a21101","type":"Range1d"},{"attributes":{"plot":{"id":"76860deb-5de5-4531-a036-6feb84d4571d","subtype":"Figure","type":"Plot"}},"id":"c1bc02ab-1256-4b9b-981c-8dd236a2013a","type":"PanTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{